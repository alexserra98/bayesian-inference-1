# %% [markdown]
# # Gibbs Sampling from errors-in model

# %% [markdown]
# ### Setup

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.special import gammaln
import corner
from scipy.stats import invgamma
import seaborn as sns
from dataclasses import dataclass
from typing import Optional
import pymc as pm

# %%
N=100
@dataclass(frozen=True)
class Parameters:
    N: int
    # Chosen parameter values
    sigma_int_sqrd: float
    theta_0: float 
    theta_1: float
    x0: float 
    Rx: float # So Rx^2 = 1.0
    sigma_x_sqrd: float 
    sigma_y_sqrd: float

    # Hyperparameters for priors (not used in data generation)
    mu_x0: float
    sigma_x0_sqrd: float
    alpha_R: float
    beta_R: float
    alpha_sigma: float
    beta_sigma: float
    mu_theta: np.ndarray
    sigma_theta_squared: float 
    sigma_0_inv: float
    mu_0: float
    gamma: Optional[float] = None
    
def generate_latents(params: Parameters, n: int = None) -> tuple[np.ndarray]:
    if n is None:
        n = params.N
    x_true = np.random.normal(loc=params.x0, scale=params.Rx, size=n)
    mu_y = params.theta_0 + params.theta_1 * x_true
    y_true = np.random.normal(loc=mu_y, scale=np.sqrt(params.sigma_int_sqrd), size=n)
    return x_true, mu_y, y_true

def generate_obs(x_true: np.ndarray, y_true: np.ndarray, params: Parameters, n: int = None) -> tuple[np.ndarray]:
    if n is None:
        n = params.N
    x_obs = np.random.normal(loc=x_true, scale=np.sqrt(params.sigma_x_sqrd), size=n)
    y_obs = np.random.normal(loc=y_true, scale=np.sqrt(params.sigma_y_sqrd), size=n)
    return x_obs, y_obs

def true_relationship(x, theta_0, theta_1):
    return theta_0 + theta_1 * x

def plot_data(x_obs: np.ndarray, y_obs: np.ndarray, x_true: np.ndarray, y_true: np.ndarray,params) -> None:
    plt.figure(figsize=(8, 6))
    plt.errorbar(x_obs, y_obs, xerr=params.sigma_x_sqrd, yerr=np.sqrt(params.sigma_y_sqrd+params.sigma_int_sqrd), fmt='o', ecolor='gray', capsize=3, label='Observed data')
    plt.xlabel('x_obs')
    plt.ylabel('y_obs')
    plt.title('Synthetic Data Generated from Errors-in-Variables Model')
    plt.grid(True)
    plt.plot(x_true, y_true, label='True Relationship', color='red')
    plt.legend()
    plt.show()

def log_posterior_y(y, mu_y, sigma_y, gamma,logistic_term):
    """
    Computes the log of the posterior (up to a constant) for y:
        p(y) ∝ [1 / (1 + exp(-gamma*y))] * Normal(y; mu_y, sigma_y^2)
    """
    # Log of the logistic factor
    #  log( 1 / (1 + e^(-gamma * y)) ) = -log(1 + e^(-gamma * y))
    
    # Log of the Normal(y; mu_y, sigma_y^2)
    #  = -0.5 * log(2π σ_y^2) - (y - mu_y)^2 / (2 σ_y^2)
    # We can drop the -0.5 * log(2π σ_y^2) term if we only need proportionality
    # but including it can help with numeric stability.
    diff = y - mu_y
    normal_term = -0.5 * np.log(2.0 * np.pi * sigma_y**2) - 0.5 * (diff**2 / sigma_y**2)

    return logistic_term + normal_term

def metropolis_step(y, params, mu_y, sigma_y,logistic_term, step_size=0.1):
    """
    One Metropolis–Hastings update for y.
    Proposes y_new from a random-walk normal around current_y,
    then accepts/rejects based on the MH acceptance ratio.
    """
    # Propose a new y from Normal(current_y, step_size^2)
    y_proposal = np.random.normal(loc=y, scale=step_size)

    # Compute log posterior at current and proposed y
    logp_current = log_posterior_y(y, mu_y, sigma_y, params.gamma, logistic_term)
    logp_proposal = log_posterior_y(y_proposal, mu_y, sigma_y, params.gamma, logistic_term)

    # Compute acceptance probability
    # log-accept-ratio = logp_proposal - logp_current
    log_accept_ratio = logp_proposal - logp_current

    # Generate random uniform numbers and take log
    log_u = np.log(np.random.rand(len(y)))
        
    # Create a boolean mask for acceptance
    accept = log_u < log_accept_ratio

    # Create result array with accepted proposals and rejected originals
    result = np.copy(y)
    result[accept] = y_proposal[accept]

    return result

def sample_x_i(vars, params, x_obs):
    """
    Sample latent x for observed data points
    """
    x_i = vars["x_i"]
    x_i_start = x_i.copy()
    N = vars.get("N_obs", vars["N"])
    for i in range(N):
        sigma_xi_sqrd = 1 / (vars["theta_1"]**2 / vars["sigma_int_sqrd"] + 1 / params.sigma_x_sqrd + 1 / vars["Rx2"])
        mu_xi = sigma_xi_sqrd * (
            vars["theta_1"] * (vars["y_i"][i] - vars["theta_0"]) / vars["sigma_int_sqrd"] +
            x_obs[i] /  params.sigma_x_sqrd +
            vars["x0"] / vars["Rx2"]
        )
        x_i[i] = np.random.normal(mu_xi, np.sqrt(sigma_xi_sqrd))

    assert np.all(x_i_start[N:] == x_i[N:]), "Non-observed data points changed"
    
    return x_i[:N]

def sample_x_j(vars, params):
    """
    Sample latent x for non-observed data points
    """
    x_j = vars["x_i"]
    x_j_start = x_j.copy() 
    for j in range(vars["N_obs"], vars["N"]):
        sigma_x_sqrd = 1 / (vars["theta_1"]**2 / vars["sigma_int_sqrd"] + 1 / params.sigma_x_sqrd + 1 / vars["Rx2"])
        mu_xi = sigma_x_sqrd * (
            vars["theta_1"] * (vars["y_i"][j] - vars["theta_0"]) / vars["sigma_int_sqrd"] +
            vars["x0"] / vars["Rx2"]
        )
        x_j[j] = np.random.normal(mu_xi, np.sqrt(sigma_x_sqrd))
    
    assert np.all(x_j_start[:vars["N_obs"]] == x_j[:vars["N_obs"]]), "Observed data points changed"
    
    return x_j[vars["N_obs"]:]


def sample_y_i(vars, params, y_obs):
    sigma_yi_sqrd = np.sqrt(1/(1/vars["sigma_int_sqrd"] + 1/params.sigma_y_sqrd))
    mu_yi = (sigma_yi_sqrd**2)*(
        y_obs/params.sigma_y_sqrd 
        + (vars["theta_0"]
            + vars["theta_1"]*vars["x_i"])
            / vars["sigma_int_sqrd"])
    y_i = np.random.normal(mu_yi, sigma_yi_sqrd)
    return y_i

def sample_y_i_w_selection(vars, params, y_obs):
    """
    Sample latent y for observed data points with selection function, using MH step.
    """
    N_obs = vars["N_obs"]
    y_i = vars["y_i"][:N_obs]
    
    sigma_y = np.sqrt(1/(1/vars["sigma_int_sqrd"] + 1/params.sigma_y_sqrd))
    mu_yi = (y_obs/params.sigma_y_sqrd 
             + (vars["theta_0"] 
             + vars["theta_1"]*vars["x_i"][:N_obs])
             / vars["sigma_int_sqrd"])*sigma_y**2
    logistic_term = -np.log(1.0 + np.exp(-params.gamma * y_i))
    y_i = metropolis_step(y_i, params, mu_yi, sigma_y, logistic_term)
    assert np.all(vars["y_i"][N_obs:] == vars["y_i"][N_obs:]), "Non-observed data points changed"
    return y_i

def sample_y_j(vars, params):
    """
    Sample latent y for non-observed data points with selection function with MH step.
    """
    N_obs = vars["N_obs"]
    y_j = vars["y_i"][N_obs:]
    mu_yi = vars["theta_0"] + vars["theta_1"]*vars["x_i"][N_obs:]
    logistic_term = np.log(np.exp(-params.gamma * y_j))-np.log(1.0 + np.exp(-params.gamma * y_j[:N_obs]))
    y_j = metropolis_step(y_j, params, mu_yi, np.sqrt(vars["sigma_int_sqrd"]), logistic_term)
    assert np.all(vars["y_i"][:N_obs] == vars["y_i"][:N_obs]), "Observed data points changed"
    return y_j

def sample_theta(vars, params):
    X = np.vstack((np.ones(params.N), vars["x_i"])).T
    y = vars["y_i"]
    sigma_theta_inv = (X.T @ X) / vars["sigma_int_sqrd"] + params.sigma_0_inv
    sigma_theta = np.linalg.inv(sigma_theta_inv)
    mu_theta_post = sigma_theta @ (X.T @ y /vars["sigma_int_sqrd"] + params.sigma_0_inv @ params.mu_0)
    theta_sample = np.random.multivariate_normal(mu_theta_post, sigma_theta)
    return theta_sample

def sample_x0(vars, params):
    sigma_x0_squared_post = 1 / (params.N / vars["Rx2"] + 1 / params.sigma_x0_sqrd)
    mu_x0_post = sigma_x0_squared_post * (np.sum(vars["x_i"]) / vars["Rx2"] + params.mu_x0 / params.sigma_x0_sqrd)
    x0 = np.random.normal(mu_x0_post, np.sqrt(sigma_x0_squared_post))
    return x0

def sample_Rx2(vars, params):
    alpha_R_post = params.alpha_R + params.N / 2
    beta_R_post = params.beta_R + 0.5 * np.sum((vars["x_i"] - vars["x0"])**2)
    Rx2 = invgamma.rvs(a=alpha_R_post, scale=beta_R_post)
    return Rx2

def sample_sigma_int_sqrd(vars, params):
    alpha_sigma_int_sqrd_sqrd_post = params.alpha_sigma + params.N / 2
    beta_sigma_int_sqrd_sqrd_post = params.beta_sigma + 0.5 * np.sum((vars["y_i"] - vars["theta_0"] - vars["theta_1"] * vars["x_i"])**2)
    sigma_int_sqrd_sqrd_x2 = invgamma.rvs(a=alpha_sigma_int_sqrd_sqrd_post, scale=beta_sigma_int_sqrd_sqrd_post)
    return sigma_int_sqrd_sqrd_x2

def init_arrays(num_iterations,params):
    theta_0_samples = np.zeros(num_iterations)
    theta_1_samples = np.zeros(num_iterations)
    x0_samples = np.zeros(num_iterations)
    Rx2_samples = np.zeros(num_iterations)
    x_i_samples = np.zeros((num_iterations, params.N))
    sigma_int_sqrd_samples = np.zeros(num_iterations)
    return {
        "theta_0": theta_0_samples,
        "theta_1": theta_1_samples, 
        "x0": x0_samples,
        "Rx2": Rx2_samples,
        "x_i": x_i_samples,
        "sigma_int_sqrd": sigma_int_sqrd_samples}
def corner_plot(samples, params):
    plot_samples = np.vstack([samples["theta_0"], samples["theta_1"], samples["x0"], samples["Rx"], samples["sigma_int"]]).T
    labels = [r"$\theta_0$", r"$\theta_1$", r"$x0$", r"$R_x$", r"$\sigma_{int}$"]
    truths = [params.theta_0, params.theta_1, params.x0, np.sqrt(params.Rx), np.sqrt(params.sigma_int_sqrd)]

    figure = corner.corner(
        plot_samples,
        labels=labels,
        truths=truths,
        show_titles=True,
        quantiles=[0.16, 0.5, 0.84],
        title_fmt=".2f",
        title_kwargs={"fontsize": 12}
    )

    plt.show()

def plot_marginal(samples, x_true):
    indices = [23, 67, 43]
    x_i_samples_selected = samples["x_i"][:, indices]
    x_i_true_selected = x_true[indices]

    num_selected = len(indices)
    fig, axes = plt.subplots(1, num_selected, figsize=(5 * num_selected, 4))

    for i, idx in enumerate(indices):
        ax = axes[i] if num_selected > 1 else axes
        sns.histplot(x_i_samples_selected[:, i], bins=50, kde=True, ax=ax, color='blue')
        ax.set_xlabel(f"$x {idx}$")
        ax.set_ylabel("Density")
        ax.set_title(f"Posterior of $x {idx}$")
        ax.axvline(x_i_true_selected[i], color='red', linestyle='--', label='True value')
        ax.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Model with intrinsic dispersion

# %% [markdown]
# $$
# y_i \mid y_i^{\mathrm{obs}},\,\theta_0,\theta_1,\,x_i,\,\sigma_y,\,\sigma_{\text{int}}
# \sim \mathcal{N}\Bigl(\mu_{y_i},\,\sigma_{y_i}^2\Bigr),
# $$
# with
# $$
# \mu_{y_i} = \left(\frac{1}{\sigma_y^2} + \frac{1}{\sigma_{\text{int}}^2}\right)^{-1} \left(\frac{y_i^{\mathrm{obs}}}{\sigma_y^2} + \frac{\theta_0+\theta_1\,x_i}{\sigma_{\text{int}}^2}\right)
# $$
# and
# $$
# \sigma_{y_i}^2 = \left(\frac{1}{\sigma_y^2} + \frac{1}{\sigma_{\text{int}}^2}\right)^{-1}.
# $$

# %%
mu_theta= 0.0
sigma_theta_squared= 4.0 ** 2
sigma_0_inv= np.linalg.inv(np.diag([sigma_theta_squared, sigma_theta_squared]))
mu_0 = np.array([mu_theta, mu_theta])
params = Parameters( 
        N = 100,
        sigma_int_sqrd = 0.25,
        theta_0 = 1.0,
        theta_1 = 0.5,
        x0 = 0,
        Rx = 1,    # So Rx^2 = 1.0
        sigma_x_sqrd = 1,
        sigma_y_sqrd = 0.25,
        # Hyperparameters for priors (not used in data generation)
        mu_x0 = 1.0,
        sigma_x0_sqrd = 1.0,
        alpha_R = 0.1,
        beta_R = 1,
        alpha_sigma = 0.1,
        beta_sigma = 1,
        mu_theta= 0.0,
        sigma_theta_squared= 4.0 ** 2,
        sigma_0_inv=sigma_0_inv,
        mu_0=mu_0
        )
# Set random seed for reproducibility
np.random.seed(42)

x_true, mu_y, y_true = generate_latents(params,100)
# x_obs, y_obs = generate_obs(x_true, y_true, params,100)
x_obs = np.random.normal(loc=x_true, scale=np.sqrt(params.sigma_x_sqrd), size=params.N)
y_obs = np.random.normal(loc=mu_y, scale=np.sqrt(params.sigma_y_sqrd+ params.sigma_int_sqrd), size=params.N)
# Plot the generated data
y_true_wo_int_dip = true_relationship(x_true, params.theta_0, params.theta_1)

# %%
plot_data(
    x_obs=x_obs,
    y_obs=y_obs,
    x_true=x_true,
    y_true=y_true_wo_int_dip,
    params=params
    )

# %%
# Number of iterations for Gibbs sampler
num_iterations = 1000000

samples = init_arrays(num_iterations, params)
# Initial values

vars = {
    "theta_0": 0.0,
    "theta_1": 0.0,
    "x0": np.mean(x_obs),
    "Rx2": np.var(x_obs),
    "x_i": x_obs.copy(),
    "y_i": y_obs.copy(),
    "sigma_int_sqrd": np.std(y_obs)/2,
    "N": params.N,
}

# Start Gibbs sampling
for t in range(num_iterations):
    # Step 1: Sample x_i
    vars["x_i"] = sample_x_i(vars, params, x_obs)
    # Step 2: Sample y_i
    vars["y_i"] = sample_y_i(vars, params, y_obs)
    # Step 3: Sample theta_0 and theta_1 jointly
    vars["theta_0"], vars["theta_1"] = sample_theta(vars, params)
    # print("theta",vars["theta_0"], vars["theta_1"])
    # Step 4: Sample x0
    vars["x0"] = sample_x0(vars, params)
    # Step 5: Sample Rx^2
    vars["Rx2"] = sample_Rx2(vars, params)
    #print("Rx2",vars["Rx2"])
    # Step 6: Sample sigma_int_sqrd
    vars["sigma_int_sqrd"] = sample_sigma_int_sqrd(vars, params)
    
    for key in samples.keys():
        samples[key][t] = vars[key]
    
    if t % 500 == 0:
        print(f"Iteration {t} completed.")

# Convert Rx^2 samples to Rx samples
Rx_samples = np.sqrt(samples["Rx2"])
samples["Rx"] = Rx_samples
# Convert sigma_int_sqrd_sqrd^2 samples to sigma_int_sqrd_sqrd samples
sigma_int_sqrd_samples = np.sqrt(samples["sigma_int_sqrd"])
samples["sigma_int"] = sigma_int_sqrd_samples

# Discard burn-in samples
burn_in = 50000
for key in samples:
    samples[key] = samples[key][burn_in:]
# Out:
# Iteration 0 completed.
# Iteration 500 completed.
# Iteration 1000 completed.
# Iteration 1500 completed.
# Iteration 2000 completed.
# Iteration 2500 completed.
# Iteration 3000 completed.
# Iteration 3500 completed.
# Iteration 4000 completed.
# Iteration 4500 completed.
# Iteration 5000 completed.
# Iteration 5500 completed.
# Iteration 6000 completed.
# Iteration 6500 completed.
# Iteration 7000 completed.
# Iteration 7500 completed.
# Iteration 8000 completed.
# Iteration 8500 completed.
# Iteration 9000 completed.
# Iteration 9500 completed.
# Iteration 10000 completed.
# Iteration 10500 completed.
# Iteration 11000 completed.
# Iteration 11500 completed.
# Iteration 12000 completed.
# Iteration 12500 completed.
# Iteration 13000 completed.
# Iteration 13500 completed.
# Iteration 14000 completed.
# Iteration 14500 completed.
# Iteration 15000 completed.
# Iteration 15500 completed.
# Iteration 16000 completed.
# Iteration 16500 completed.
# Iteration 17000 completed.
# Iteration 17500 completed.
# Iteration 18000 completed.
# Iteration 18500 completed.
# Iteration 19000 completed.
# Iteration 19500 completed.
# Iteration 20000 completed.
# Iteration 20500 completed.
# Iteration 21000 completed.
# Iteration 21500 completed.
# Iteration 22000 completed.
# Iteration 22500 completed.
# Iteration 23000 completed.
# Iteration 23500 completed.
# Iteration 24000 completed.
# Iteration 24500 completed.
# Iteration 25000 completed.
# Iteration 25500 completed.
# Iteration 26000 completed.
# Iteration 26500 completed.
# Iteration 27000 completed.
# Iteration 27500 completed.
# Iteration 28000 completed.
# Iteration 28500 completed.
# Iteration 29000 completed.
# Iteration 29500 completed.
# Iteration 30000 completed.
# Iteration 30500 completed.
# Iteration 31000 completed.
# Iteration 31500 completed.
# Iteration 32000 completed.
# Iteration 32500 completed.
# Iteration 33000 completed.
# Iteration 33500 completed.
# Iteration 34000 completed.
# Iteration 34500 completed.
# Iteration 35000 completed.
# Iteration 35500 completed.
# Iteration 36000 completed.
# Iteration 36500 completed.
# Iteration 37000 completed.
# Iteration 37500 completed.
# Iteration 38000 completed.
# Iteration 38500 completed.
# Iteration 39000 completed.
# Iteration 39500 completed.
# Iteration 40000 completed.
# Iteration 40500 completed.
# Iteration 41000 completed.
# Iteration 41500 completed.
# Iteration 42000 completed.
# Iteration 42500 completed.
# Iteration 43000 completed.
# Iteration 43500 completed.
# Iteration 44000 completed.
# Iteration 44500 completed.
# Iteration 45000 completed.
# Iteration 45500 completed.
# Iteration 46000 completed.
# Iteration 46500 completed.
# Iteration 47000 completed.
# Iteration 47500 completed.
# Iteration 48000 completed.
# Iteration 48500 completed.
# Iteration 49000 completed.
# Iteration 49500 completed.
# Iteration 50000 completed.
# Iteration 50500 completed.
# Iteration 51000 completed.
# Iteration 51500 completed.
# Iteration 52000 completed.
# Iteration 52500 completed.
# Iteration 53000 completed.
# Iteration 53500 completed.
# Iteration 54000 completed.
# Iteration 54500 completed.
# Iteration 55000 completed.
# Iteration 55500 completed.
# Iteration 56000 completed.
# Iteration 56500 completed.
# Iteration 57000 completed.
# Iteration 57500 completed.
# Iteration 58000 completed.
# Iteration 58500 completed.
# Iteration 59000 completed.
# Iteration 59500 completed.
# Iteration 60000 completed.
# Iteration 60500 completed.
# Iteration 61000 completed.
# Iteration 61500 completed.
# Iteration 62000 completed.
# Iteration 62500 completed.
# Iteration 63000 completed.
# Iteration 63500 completed.
# Iteration 64000 completed.
# Iteration 64500 completed.
# Iteration 65000 completed.
# Iteration 65500 completed.
# Iteration 66000 completed.
# Iteration 66500 completed.
# Iteration 67000 completed.
# Iteration 67500 completed.
# Iteration 68000 completed.
# Iteration 68500 completed.
# Iteration 69000 completed.
# Iteration 69500 completed.
# Iteration 70000 completed.
# Iteration 70500 completed.
# Iteration 71000 completed.
# Iteration 71500 completed.
# Iteration 72000 completed.
# Iteration 72500 completed.
# Iteration 73000 completed.
# Iteration 73500 completed.
# Iteration 74000 completed.
# Iteration 74500 completed.
# Iteration 75000 completed.
# Iteration 75500 completed.
# Iteration 76000 completed.
# Iteration 76500 completed.
# Iteration 77000 completed.
# Iteration 77500 completed.
# Iteration 78000 completed.
# Iteration 78500 completed.
# Iteration 79000 completed.
# Iteration 79500 completed.
# Iteration 80000 completed.
# Iteration 80500 completed.
# Iteration 81000 completed.
# Iteration 81500 completed.
# Iteration 82000 completed.
# Iteration 82500 completed.
# Iteration 83000 completed.
# Iteration 83500 completed.
# Iteration 84000 completed.
# Iteration 84500 completed.
# Iteration 85000 completed.
# Iteration 85500 completed.
# Iteration 86000 completed.
# Iteration 86500 completed.
# Iteration 87000 completed.
# Iteration 87500 completed.
# Iteration 88000 completed.
# Iteration 88500 completed.
# Iteration 89000 completed.
# Iteration 89500 completed.
# Iteration 90000 completed.
# Iteration 90500 completed.
# Iteration 91000 completed.
# Iteration 91500 completed.
# Iteration 92000 completed.
# Iteration 92500 completed.
# Iteration 93000 completed.
# Iteration 93500 completed.
# Iteration 94000 completed.
# Iteration 94500 completed.
# Iteration 95000 completed.
# Iteration 95500 completed.
# Iteration 96000 completed.
# Iteration 96500 completed.
# Iteration 97000 completed.
# Iteration 97500 completed.
# Iteration 98000 completed.
# Iteration 98500 completed.
# Iteration 99000 completed.
# Iteration 99500 completed.
# Iteration 100000 completed.
# Iteration 100500 completed.
# Iteration 101000 completed.
# Iteration 101500 completed.
# Iteration 102000 completed.
# Iteration 102500 completed.
# Iteration 103000 completed.
# Iteration 103500 completed.
# Iteration 104000 completed.
# Iteration 104500 completed.
# Iteration 105000 completed.
# Iteration 105500 completed.
# Iteration 106000 completed.
# Iteration 106500 completed.
# Iteration 107000 completed.
# Iteration 107500 completed.
# Iteration 108000 completed.
# Iteration 108500 completed.
# Iteration 109000 completed.
# Iteration 109500 completed.
# Iteration 110000 completed.
# Iteration 110500 completed.
# Iteration 111000 completed.
# Iteration 111500 completed.
# Iteration 112000 completed.
# Iteration 112500 completed.
# Iteration 113000 completed.
# Iteration 113500 completed.
# Iteration 114000 completed.
# Iteration 114500 completed.
# Iteration 115000 completed.
# Iteration 115500 completed.
# Iteration 116000 completed.
# Iteration 116500 completed.
# Iteration 117000 completed.
# Iteration 117500 completed.
# Iteration 118000 completed.
# Iteration 118500 completed.
# Iteration 119000 completed.
# Iteration 119500 completed.
# Iteration 120000 completed.
# Iteration 120500 completed.
# Iteration 121000 completed.
# Iteration 121500 completed.
# Iteration 122000 completed.
# Iteration 122500 completed.
# Iteration 123000 completed.
# Iteration 123500 completed.
# Iteration 124000 completed.
# Iteration 124500 completed.
# Iteration 125000 completed.
# Iteration 125500 completed.
# Iteration 126000 completed.
# Iteration 126500 completed.
# Iteration 127000 completed.
# Iteration 127500 completed.
# Iteration 128000 completed.
# Iteration 128500 completed.
# Iteration 129000 completed.
# Iteration 129500 completed.
# Iteration 130000 completed.
# Iteration 130500 completed.
# Iteration 131000 completed.
# Iteration 131500 completed.
# Iteration 132000 completed.
# Iteration 132500 completed.
# Iteration 133000 completed.
# Iteration 133500 completed.
# Iteration 134000 completed.
# Iteration 134500 completed.
# Iteration 135000 completed.
# Iteration 135500 completed.
# Iteration 136000 completed.
# Iteration 136500 completed.
# Iteration 137000 completed.
# Iteration 137500 completed.
# Iteration 138000 completed.
# Iteration 138500 completed.
# Iteration 139000 completed.
# Iteration 139500 completed.
# Iteration 140000 completed.
# Iteration 140500 completed.
# Iteration 141000 completed.
# Iteration 141500 completed.
# Iteration 142000 completed.
# Iteration 142500 completed.
# Iteration 143000 completed.
# Iteration 143500 completed.
# Iteration 144000 completed.
# Iteration 144500 completed.
# Iteration 145000 completed.
# Iteration 145500 completed.
# Iteration 146000 completed.
# Iteration 146500 completed.
# Iteration 147000 completed.
# Iteration 147500 completed.
# Iteration 148000 completed.
# Iteration 148500 completed.
# Iteration 149000 completed.
# Iteration 149500 completed.
# Iteration 150000 completed.
# Iteration 150500 completed.
# Iteration 151000 completed.
# Iteration 151500 completed.
# Iteration 152000 completed.
# Iteration 152500 completed.
# Iteration 153000 completed.
# Iteration 153500 completed.
# Iteration 154000 completed.
# Iteration 154500 completed.
# Iteration 155000 completed.
# Iteration 155500 completed.
# Iteration 156000 completed.
# Iteration 156500 completed.
# Iteration 157000 completed.
# Iteration 157500 completed.
# Iteration 158000 completed.
# Iteration 158500 completed.
# Iteration 159000 completed.
# Iteration 159500 completed.
# Iteration 160000 completed.
# Iteration 160500 completed.
# Iteration 161000 completed.
# Iteration 161500 completed.
# Iteration 162000 completed.
# Iteration 162500 completed.
# Iteration 163000 completed.
# Iteration 163500 completed.
# Iteration 164000 completed.
# Iteration 164500 completed.
# Iteration 165000 completed.
# Iteration 165500 completed.
# Iteration 166000 completed.
# Iteration 166500 completed.
# Iteration 167000 completed.
# Iteration 167500 completed.
# Iteration 168000 completed.
# Iteration 168500 completed.
# Iteration 169000 completed.
# Iteration 169500 completed.
# Iteration 170000 completed.
# Iteration 170500 completed.
# Iteration 171000 completed.
# Iteration 171500 completed.
# Iteration 172000 completed.
# Iteration 172500 completed.
# Iteration 173000 completed.
# Iteration 173500 completed.
# Iteration 174000 completed.
# Iteration 174500 completed.
# Iteration 175000 completed.
# Iteration 175500 completed.
# Iteration 176000 completed.
# Iteration 176500 completed.
# Iteration 177000 completed.
# Iteration 177500 completed.
# Iteration 178000 completed.
# Iteration 178500 completed.
# Iteration 179000 completed.
# Iteration 179500 completed.
# Iteration 180000 completed.
# Iteration 180500 completed.
# Iteration 181000 completed.
# Iteration 181500 completed.
# Iteration 182000 completed.
# Iteration 182500 completed.
# Iteration 183000 completed.
# Iteration 183500 completed.
# Iteration 184000 completed.
# Iteration 184500 completed.
# Iteration 185000 completed.
# Iteration 185500 completed.
# Iteration 186000 completed.
# Iteration 186500 completed.
# Iteration 187000 completed.
# Iteration 187500 completed.
# Iteration 188000 completed.
# Iteration 188500 completed.
# Iteration 189000 completed.
# Iteration 189500 completed.
# Iteration 190000 completed.
# Iteration 190500 completed.
# Iteration 191000 completed.
# Iteration 191500 completed.
# Iteration 192000 completed.
# Iteration 192500 completed.
# Iteration 193000 completed.
# Iteration 193500 completed.
# Iteration 194000 completed.
# Iteration 194500 completed.
# Iteration 195000 completed.
# Iteration 195500 completed.
# Iteration 196000 completed.
# Iteration 196500 completed.
# Iteration 197000 completed.
# Iteration 197500 completed.
# Iteration 198000 completed.
# Iteration 198500 completed.
# Iteration 199000 completed.
# Iteration 199500 completed.
# Iteration 200000 completed.
# Iteration 200500 completed.
# Iteration 201000 completed.
# Iteration 201500 completed.
# Iteration 202000 completed.
# Iteration 202500 completed.
# Iteration 203000 completed.
# Iteration 203500 completed.
# Iteration 204000 completed.
# Iteration 204500 completed.
# Iteration 205000 completed.
# Iteration 205500 completed.
# Iteration 206000 completed.
# Iteration 206500 completed.
# Iteration 207000 completed.
# Iteration 207500 completed.
# Iteration 208000 completed.
# Iteration 208500 completed.
# Iteration 209000 completed.
# Iteration 209500 completed.
# Iteration 210000 completed.
# Iteration 210500 completed.
# Iteration 211000 completed.
# Iteration 211500 completed.
# Iteration 212000 completed.
# Iteration 212500 completed.
# Iteration 213000 completed.
# Iteration 213500 completed.
# Iteration 214000 completed.
# Iteration 214500 completed.
# Iteration 215000 completed.
# Iteration 215500 completed.
# Iteration 216000 completed.
# Iteration 216500 completed.
# Iteration 217000 completed.
# Iteration 217500 completed.
# Iteration 218000 completed.
# Iteration 218500 completed.
# Iteration 219000 completed.
# Iteration 219500 completed.
# Iteration 220000 completed.
# Iteration 220500 completed.
# Iteration 221000 completed.
# Iteration 221500 completed.
# Iteration 222000 completed.
# Iteration 222500 completed.
# Iteration 223000 completed.
# Iteration 223500 completed.
# Iteration 224000 completed.
# Iteration 224500 completed.
# Iteration 225000 completed.
# Iteration 225500 completed.
# Iteration 226000 completed.
# Iteration 226500 completed.
# Iteration 227000 completed.
# Iteration 227500 completed.
# Iteration 228000 completed.
# Iteration 228500 completed.
# Iteration 229000 completed.
# Iteration 229500 completed.
# Iteration 230000 completed.
# Iteration 230500 completed.
# Iteration 231000 completed.
# Iteration 231500 completed.
# Iteration 232000 completed.
# Iteration 232500 completed.
# Iteration 233000 completed.
# Iteration 233500 completed.
# Iteration 234000 completed.
# Iteration 234500 completed.
# Iteration 235000 completed.
# Iteration 235500 completed.
# Iteration 236000 completed.
# Iteration 236500 completed.
# Iteration 237000 completed.
# Iteration 237500 completed.
# Iteration 238000 completed.
# Iteration 238500 completed.
# Iteration 239000 completed.
# Iteration 239500 completed.
# Iteration 240000 completed.
# Iteration 240500 completed.
# Iteration 241000 completed.
# Iteration 241500 completed.
# Iteration 242000 completed.
# Iteration 242500 completed.
# Iteration 243000 completed.
# Iteration 243500 completed.
# Iteration 244000 completed.
# Iteration 244500 completed.
# Iteration 245000 completed.
# Iteration 245500 completed.
# Iteration 246000 completed.
# Iteration 246500 completed.
# Iteration 247000 completed.
# Iteration 247500 completed.
# Iteration 248000 completed.
# Iteration 248500 completed.
# Iteration 249000 completed.
# Iteration 249500 completed.
# Iteration 250000 completed.
# Iteration 250500 completed.
# Iteration 251000 completed.
# Iteration 251500 completed.
# Iteration 252000 completed.
# Iteration 252500 completed.
# Iteration 253000 completed.
# Iteration 253500 completed.
# Iteration 254000 completed.
# Iteration 254500 completed.
# Iteration 255000 completed.
# Iteration 255500 completed.
# Iteration 256000 completed.
# Iteration 256500 completed.
# Iteration 257000 completed.
# Iteration 257500 completed.
# Iteration 258000 completed.
# Iteration 258500 completed.
# Iteration 259000 completed.
# Iteration 259500 completed.
# Iteration 260000 completed.
# Iteration 260500 completed.
# Iteration 261000 completed.
# Iteration 261500 completed.
# Iteration 262000 completed.
# Iteration 262500 completed.
# Iteration 263000 completed.
# Iteration 263500 completed.
# Iteration 264000 completed.
# Iteration 264500 completed.
# Iteration 265000 completed.
# Iteration 265500 completed.
# Iteration 266000 completed.
# Iteration 266500 completed.
# Iteration 267000 completed.
# Iteration 267500 completed.
# Iteration 268000 completed.
# Iteration 268500 completed.
# Iteration 269000 completed.
# Iteration 269500 completed.
# Iteration 270000 completed.
# Iteration 270500 completed.
# Iteration 271000 completed.
# Iteration 271500 completed.
# Iteration 272000 completed.
# Iteration 272500 completed.
# Iteration 273000 completed.
# Iteration 273500 completed.
# Iteration 274000 completed.
# Iteration 274500 completed.
# Iteration 275000 completed.
# Iteration 275500 completed.
# Iteration 276000 completed.
# Iteration 276500 completed.
# Iteration 277000 completed.
# Iteration 277500 completed.
# Iteration 278000 completed.
# Iteration 278500 completed.
# Iteration 279000 completed.
# Iteration 279500 completed.
# Iteration 280000 completed.
# Iteration 280500 completed.
# Iteration 281000 completed.
# Iteration 281500 completed.
# Iteration 282000 completed.
# Iteration 282500 completed.
# Iteration 283000 completed.
# Iteration 283500 completed.
# Iteration 284000 completed.
# Iteration 284500 completed.
# Iteration 285000 completed.
# Iteration 285500 completed.
# Iteration 286000 completed.
# Iteration 286500 completed.
# Iteration 287000 completed.
# Iteration 287500 completed.
# Iteration 288000 completed.
# Iteration 288500 completed.
# Iteration 289000 completed.
# Iteration 289500 completed.
# Iteration 290000 completed.
# Iteration 290500 completed.
# Iteration 291000 completed.
# Iteration 291500 completed.
# Iteration 292000 completed.
# Iteration 292500 completed.
# Iteration 293000 completed.
# Iteration 293500 completed.
# Iteration 294000 completed.
# Iteration 294500 completed.
# Iteration 295000 completed.
# Iteration 295500 completed.
# Iteration 296000 completed.
# Iteration 296500 completed.
# Iteration 297000 completed.
# Iteration 297500 completed.
# Iteration 298000 completed.
# Iteration 298500 completed.
# Iteration 299000 completed.
# Iteration 299500 completed.
# Iteration 300000 completed.
# Iteration 300500 completed.
# Iteration 301000 completed.
# Iteration 301500 completed.
# Iteration 302000 completed.
# Iteration 302500 completed.
# Iteration 303000 completed.
# Iteration 303500 completed.
# Iteration 304000 completed.
# Iteration 304500 completed.
# Iteration 305000 completed.
# Iteration 305500 completed.
# Iteration 306000 completed.
# Iteration 306500 completed.
# Iteration 307000 completed.
# Iteration 307500 completed.
# Iteration 308000 completed.
# Iteration 308500 completed.
# Iteration 309000 completed.
# Iteration 309500 completed.
# Iteration 310000 completed.
# Iteration 310500 completed.
# Iteration 311000 completed.
# Iteration 311500 completed.
# Iteration 312000 completed.
# Iteration 312500 completed.
# Iteration 313000 completed.
# Iteration 313500 completed.
# Iteration 314000 completed.
# Iteration 314500 completed.
# Iteration 315000 completed.
# Iteration 315500 completed.
# Iteration 316000 completed.
# Iteration 316500 completed.
# Iteration 317000 completed.
# Iteration 317500 completed.
# Iteration 318000 completed.
# Iteration 318500 completed.
# Iteration 319000 completed.
# Iteration 319500 completed.
# Iteration 320000 completed.
# Iteration 320500 completed.
# Iteration 321000 completed.
# Iteration 321500 completed.
# Iteration 322000 completed.
# Iteration 322500 completed.
# Iteration 323000 completed.
# Iteration 323500 completed.
# Iteration 324000 completed.
# Iteration 324500 completed.
# Iteration 325000 completed.
# Iteration 325500 completed.
# Iteration 326000 completed.
# Iteration 326500 completed.
# Iteration 327000 completed.
# Iteration 327500 completed.
# Iteration 328000 completed.
# Iteration 328500 completed.
# Iteration 329000 completed.
# Iteration 329500 completed.
# Iteration 330000 completed.
# Iteration 330500 completed.
# Iteration 331000 completed.
# Iteration 331500 completed.
# Iteration 332000 completed.
# Iteration 332500 completed.
# Iteration 333000 completed.
# Iteration 333500 completed.
# Iteration 334000 completed.
# Iteration 334500 completed.
# Iteration 335000 completed.
# Iteration 335500 completed.
# Iteration 336000 completed.
# Iteration 336500 completed.
# Iteration 337000 completed.
# Iteration 337500 completed.
# Iteration 338000 completed.
# Iteration 338500 completed.
# Iteration 339000 completed.
# Iteration 339500 completed.
# Iteration 340000 completed.
# Iteration 340500 completed.
# Iteration 341000 completed.
# Iteration 341500 completed.
# Iteration 342000 completed.
# Iteration 342500 completed.
# Iteration 343000 completed.
# Iteration 343500 completed.
# Iteration 344000 completed.
# Iteration 344500 completed.
# Iteration 345000 completed.
# Iteration 345500 completed.
# Iteration 346000 completed.
# Iteration 346500 completed.
# Iteration 347000 completed.
# Iteration 347500 completed.
# Iteration 348000 completed.
# Iteration 348500 completed.
# Iteration 349000 completed.
# Iteration 349500 completed.
# Iteration 350000 completed.
# Iteration 350500 completed.
# Iteration 351000 completed.
# Iteration 351500 completed.
# Iteration 352000 completed.
# Iteration 352500 completed.
# Iteration 353000 completed.
# Iteration 353500 completed.
# Iteration 354000 completed.
# Iteration 354500 completed.
# Iteration 355000 completed.
# Iteration 355500 completed.
# Iteration 356000 completed.
# Iteration 356500 completed.
# Iteration 357000 completed.
# Iteration 357500 completed.
# Iteration 358000 completed.
# Iteration 358500 completed.
# Iteration 359000 completed.
# Iteration 359500 completed.
# Iteration 360000 completed.
# Iteration 360500 completed.
# Iteration 361000 completed.
# Iteration 361500 completed.
# Iteration 362000 completed.
# Iteration 362500 completed.
# Iteration 363000 completed.
# Iteration 363500 completed.
# Iteration 364000 completed.
# Iteration 364500 completed.
# Iteration 365000 completed.
# Iteration 365500 completed.
# Iteration 366000 completed.
# Iteration 366500 completed.
# Iteration 367000 completed.
# Iteration 367500 completed.
# Iteration 368000 completed.
# Iteration 368500 completed.
# Iteration 369000 completed.
# Iteration 369500 completed.
# Iteration 370000 completed.
# Iteration 370500 completed.
# Iteration 371000 completed.
# Iteration 371500 completed.
# Iteration 372000 completed.
# Iteration 372500 completed.
# Iteration 373000 completed.
# Iteration 373500 completed.
# Iteration 374000 completed.
# Iteration 374500 completed.
# Iteration 375000 completed.
# Iteration 375500 completed.
# Iteration 376000 completed.
# Iteration 376500 completed.
# Iteration 377000 completed.
# Iteration 377500 completed.
# Iteration 378000 completed.
# Iteration 378500 completed.
# Iteration 379000 completed.
# Iteration 379500 completed.
# Iteration 380000 completed.
# Iteration 380500 completed.
# Iteration 381000 completed.
# Iteration 381500 completed.
# Iteration 382000 completed.
# Iteration 382500 completed.
# Iteration 383000 completed.
# Iteration 383500 completed.
# Iteration 384000 completed.
# Iteration 384500 completed.
# Iteration 385000 completed.
# Iteration 385500 completed.
# Iteration 386000 completed.
# Iteration 386500 completed.
# Iteration 387000 completed.
# Iteration 387500 completed.
# Iteration 388000 completed.
# Iteration 388500 completed.
# Iteration 389000 completed.
# Iteration 389500 completed.
# Iteration 390000 completed.
# Iteration 390500 completed.
# Iteration 391000 completed.
# Iteration 391500 completed.
# Iteration 392000 completed.
# Iteration 392500 completed.
# Iteration 393000 completed.
# Iteration 393500 completed.
# Iteration 394000 completed.
# Iteration 394500 completed.
# Iteration 395000 completed.
# Iteration 395500 completed.
# Iteration 396000 completed.
# Iteration 396500 completed.
# Iteration 397000 completed.
# Iteration 397500 completed.
# Iteration 398000 completed.
# Iteration 398500 completed.
# Iteration 399000 completed.
# Iteration 399500 completed.
# Iteration 400000 completed.
# Iteration 400500 completed.
# Iteration 401000 completed.
# Iteration 401500 completed.
# Iteration 402000 completed.
# Iteration 402500 completed.
# Iteration 403000 completed.
# Iteration 403500 completed.
# Iteration 404000 completed.
# Iteration 404500 completed.
# Iteration 405000 completed.
# Iteration 405500 completed.
# Iteration 406000 completed.
# Iteration 406500 completed.
# Iteration 407000 completed.
# Iteration 407500 completed.
# Iteration 408000 completed.
# Iteration 408500 completed.
# Iteration 409000 completed.
# Iteration 409500 completed.
# Iteration 410000 completed.
# Iteration 410500 completed.
# Iteration 411000 completed.
# Iteration 411500 completed.
# Iteration 412000 completed.
# Iteration 412500 completed.
# Iteration 413000 completed.
# Iteration 413500 completed.
# Iteration 414000 completed.
# Iteration 414500 completed.
# Iteration 415000 completed.
# Iteration 415500 completed.
# Iteration 416000 completed.
# Iteration 416500 completed.
# Iteration 417000 completed.
# Iteration 417500 completed.
# Iteration 418000 completed.
# Iteration 418500 completed.
# Iteration 419000 completed.
# Iteration 419500 completed.
# Iteration 420000 completed.
# Iteration 420500 completed.
# Iteration 421000 completed.
# Iteration 421500 completed.
# Iteration 422000 completed.
# Iteration 422500 completed.
# Iteration 423000 completed.
# Iteration 423500 completed.
# Iteration 424000 completed.
# Iteration 424500 completed.
# Iteration 425000 completed.
# Iteration 425500 completed.
# Iteration 426000 completed.
# Iteration 426500 completed.
# Iteration 427000 completed.
# Iteration 427500 completed.
# Iteration 428000 completed.
# Iteration 428500 completed.
# Iteration 429000 completed.
# Iteration 429500 completed.
# Iteration 430000 completed.
# Iteration 430500 completed.
# Iteration 431000 completed.
# Iteration 431500 completed.
# Iteration 432000 completed.
# Iteration 432500 completed.
# Iteration 433000 completed.
# Iteration 433500 completed.
# Iteration 434000 completed.
# Iteration 434500 completed.
# Iteration 435000 completed.
# Iteration 435500 completed.
# Iteration 436000 completed.
# Iteration 436500 completed.
# Iteration 437000 completed.
# Iteration 437500 completed.
# Iteration 438000 completed.
# Iteration 438500 completed.
# Iteration 439000 completed.
# Iteration 439500 completed.
# Iteration 440000 completed.
# Iteration 440500 completed.
# Iteration 441000 completed.
# Iteration 441500 completed.
# Iteration 442000 completed.
# Iteration 442500 completed.
# Iteration 443000 completed.
# Iteration 443500 completed.
# Iteration 444000 completed.
# Iteration 444500 completed.
# Iteration 445000 completed.
# Iteration 445500 completed.
# Iteration 446000 completed.
# Iteration 446500 completed.
# Iteration 447000 completed.
# Iteration 447500 completed.
# Iteration 448000 completed.
# Iteration 448500 completed.
# Iteration 449000 completed.
# Iteration 449500 completed.
# Iteration 450000 completed.
# Iteration 450500 completed.
# Iteration 451000 completed.
# Iteration 451500 completed.
# Iteration 452000 completed.
# Iteration 452500 completed.
# Iteration 453000 completed.
# Iteration 453500 completed.
# Iteration 454000 completed.
# Iteration 454500 completed.
# Iteration 455000 completed.
# Iteration 455500 completed.
# Iteration 456000 completed.
# Iteration 456500 completed.
# Iteration 457000 completed.
# Iteration 457500 completed.
# Iteration 458000 completed.
# Iteration 458500 completed.
# Iteration 459000 completed.
# Iteration 459500 completed.
# Iteration 460000 completed.
# Iteration 460500 completed.
# Iteration 461000 completed.
# Iteration 461500 completed.
# Iteration 462000 completed.
# Iteration 462500 completed.
# Iteration 463000 completed.
# Iteration 463500 completed.
# Iteration 464000 completed.
# Iteration 464500 completed.
# Iteration 465000 completed.
# Iteration 465500 completed.
# Iteration 466000 completed.
# Iteration 466500 completed.
# Iteration 467000 completed.
# Iteration 467500 completed.
# Iteration 468000 completed.
# Iteration 468500 completed.
# Iteration 469000 completed.
# Iteration 469500 completed.
# Iteration 470000 completed.
# Iteration 470500 completed.
# Iteration 471000 completed.
# Iteration 471500 completed.
# Iteration 472000 completed.
# Iteration 472500 completed.
# Iteration 473000 completed.
# Iteration 473500 completed.
# Iteration 474000 completed.
# Iteration 474500 completed.
# Iteration 475000 completed.
# Iteration 475500 completed.
# Iteration 476000 completed.
# Iteration 476500 completed.
# Iteration 477000 completed.
# Iteration 477500 completed.
# Iteration 478000 completed.
# Iteration 478500 completed.
# Iteration 479000 completed.
# Iteration 479500 completed.
# Iteration 480000 completed.
# Iteration 480500 completed.
# Iteration 481000 completed.
# Iteration 481500 completed.
# Iteration 482000 completed.
# Iteration 482500 completed.
# Iteration 483000 completed.
# Iteration 483500 completed.
# Iteration 484000 completed.
# Iteration 484500 completed.
# Iteration 485000 completed.
# Iteration 485500 completed.
# Iteration 486000 completed.
# Iteration 486500 completed.
# Iteration 487000 completed.
# Iteration 487500 completed.
# Iteration 488000 completed.
# Iteration 488500 completed.
# Iteration 489000 completed.
# Iteration 489500 completed.
# Iteration 490000 completed.
# Iteration 490500 completed.
# Iteration 491000 completed.
# Iteration 491500 completed.
# Iteration 492000 completed.
# Iteration 492500 completed.
# Iteration 493000 completed.
# Iteration 493500 completed.
# Iteration 494000 completed.
# Iteration 494500 completed.
# Iteration 495000 completed.
# Iteration 495500 completed.
# Iteration 496000 completed.
# Iteration 496500 completed.
# Iteration 497000 completed.
# Iteration 497500 completed.
# Iteration 498000 completed.
# Iteration 498500 completed.
# Iteration 499000 completed.
# Iteration 499500 completed.
# Iteration 500000 completed.
# Iteration 500500 completed.
# Iteration 501000 completed.
# Iteration 501500 completed.
# Iteration 502000 completed.
# Iteration 502500 completed.
# Iteration 503000 completed.
# Iteration 503500 completed.
# Iteration 504000 completed.
# Iteration 504500 completed.
# Iteration 505000 completed.
# Iteration 505500 completed.
# Iteration 506000 completed.
# Iteration 506500 completed.
# Iteration 507000 completed.
# Iteration 507500 completed.
# Iteration 508000 completed.
# Iteration 508500 completed.
# Iteration 509000 completed.
# Iteration 509500 completed.
# Iteration 510000 completed.
# Iteration 510500 completed.
# Iteration 511000 completed.
# Iteration 511500 completed.
# Iteration 512000 completed.
# Iteration 512500 completed.
# Iteration 513000 completed.
# Iteration 513500 completed.
# Iteration 514000 completed.
# Iteration 514500 completed.
# Iteration 515000 completed.
# Iteration 515500 completed.
# Iteration 516000 completed.
# Iteration 516500 completed.
# Iteration 517000 completed.
# Iteration 517500 completed.
# Iteration 518000 completed.
# Iteration 518500 completed.
# Iteration 519000 completed.
# Iteration 519500 completed.
# Iteration 520000 completed.
# Iteration 520500 completed.
# Iteration 521000 completed.
# Iteration 521500 completed.
# Iteration 522000 completed.
# Iteration 522500 completed.
# Iteration 523000 completed.
# Iteration 523500 completed.
# Iteration 524000 completed.
# Iteration 524500 completed.
# Iteration 525000 completed.
# Iteration 525500 completed.
# Iteration 526000 completed.
# Iteration 526500 completed.
# Iteration 527000 completed.
# Iteration 527500 completed.
# Iteration 528000 completed.
# Iteration 528500 completed.
# Iteration 529000 completed.
# Iteration 529500 completed.
# Iteration 530000 completed.
# Iteration 530500 completed.
# Iteration 531000 completed.
# Iteration 531500 completed.
# Iteration 532000 completed.
# Iteration 532500 completed.
# Iteration 533000 completed.
# Iteration 533500 completed.
# Iteration 534000 completed.
# Iteration 534500 completed.
# Iteration 535000 completed.
# Iteration 535500 completed.
# Iteration 536000 completed.
# Iteration 536500 completed.
# Iteration 537000 completed.
# Iteration 537500 completed.
# Iteration 538000 completed.
# Iteration 538500 completed.
# Iteration 539000 completed.
# Iteration 539500 completed.
# Iteration 540000 completed.
# Iteration 540500 completed.
# Iteration 541000 completed.
# Iteration 541500 completed.
# Iteration 542000 completed.
# Iteration 542500 completed.
# Iteration 543000 completed.
# Iteration 543500 completed.
# Iteration 544000 completed.
# Iteration 544500 completed.
# Iteration 545000 completed.
# Iteration 545500 completed.
# Iteration 546000 completed.
# Iteration 546500 completed.
# Iteration 547000 completed.
# Iteration 547500 completed.
# Iteration 548000 completed.
# Iteration 548500 completed.
# Iteration 549000 completed.
# Iteration 549500 completed.
# Iteration 550000 completed.
# Iteration 550500 completed.
# Iteration 551000 completed.
# Iteration 551500 completed.
# Iteration 552000 completed.
# Iteration 552500 completed.
# Iteration 553000 completed.
# Iteration 553500 completed.
# Iteration 554000 completed.
# Iteration 554500 completed.
# Iteration 555000 completed.
# Iteration 555500 completed.
# Iteration 556000 completed.
# Iteration 556500 completed.
# Iteration 557000 completed.
# Iteration 557500 completed.
# Iteration 558000 completed.
# Iteration 558500 completed.
# Iteration 559000 completed.
# Iteration 559500 completed.
# Iteration 560000 completed.
# Iteration 560500 completed.
# Iteration 561000 completed.
# Iteration 561500 completed.
# Iteration 562000 completed.
# Iteration 562500 completed.
# Iteration 563000 completed.
# Iteration 563500 completed.
# Iteration 564000 completed.
# Iteration 564500 completed.
# Iteration 565000 completed.
# Iteration 565500 completed.
# Iteration 566000 completed.
# Iteration 566500 completed.
# Iteration 567000 completed.
# Iteration 567500 completed.
# Iteration 568000 completed.
# Iteration 568500 completed.
# Iteration 569000 completed.
# Iteration 569500 completed.
# Iteration 570000 completed.
# Iteration 570500 completed.
# Iteration 571000 completed.
# Iteration 571500 completed.
# Iteration 572000 completed.
# Iteration 572500 completed.
# Iteration 573000 completed.
# Iteration 573500 completed.
# Iteration 574000 completed.
# Iteration 574500 completed.
# Iteration 575000 completed.
# Iteration 575500 completed.
# Iteration 576000 completed.
# Iteration 576500 completed.
# Iteration 577000 completed.
# Iteration 577500 completed.
# Iteration 578000 completed.
# Iteration 578500 completed.
# Iteration 579000 completed.
# Iteration 579500 completed.
# Iteration 580000 completed.
# Iteration 580500 completed.
# Iteration 581000 completed.
# Iteration 581500 completed.
# Iteration 582000 completed.
# Iteration 582500 completed.
# Iteration 583000 completed.
# Iteration 583500 completed.
# Iteration 584000 completed.
# Iteration 584500 completed.
# Iteration 585000 completed.
# Iteration 585500 completed.
# Iteration 586000 completed.
# Iteration 586500 completed.
# Iteration 587000 completed.
# Iteration 587500 completed.
# Iteration 588000 completed.
# Iteration 588500 completed.
# Iteration 589000 completed.
# Iteration 589500 completed.
# Iteration 590000 completed.
# Iteration 590500 completed.
# Iteration 591000 completed.
# Iteration 591500 completed.
# Iteration 592000 completed.
# Iteration 592500 completed.
# Iteration 593000 completed.
# Iteration 593500 completed.
# Iteration 594000 completed.
# Iteration 594500 completed.
# Iteration 595000 completed.
# Iteration 595500 completed.
# Iteration 596000 completed.
# Iteration 596500 completed.
# Iteration 597000 completed.
# Iteration 597500 completed.
# Iteration 598000 completed.
# Iteration 598500 completed.
# Iteration 599000 completed.
# Iteration 599500 completed.
# Iteration 600000 completed.
# Iteration 600500 completed.
# Iteration 601000 completed.
# Iteration 601500 completed.
# Iteration 602000 completed.
# Iteration 602500 completed.
# Iteration 603000 completed.
# Iteration 603500 completed.
# Iteration 604000 completed.
# Iteration 604500 completed.
# Iteration 605000 completed.
# Iteration 605500 completed.
# Iteration 606000 completed.
# Iteration 606500 completed.
# Iteration 607000 completed.
# Iteration 607500 completed.
# Iteration 608000 completed.
# Iteration 608500 completed.
# Iteration 609000 completed.
# Iteration 609500 completed.
# Iteration 610000 completed.
# Iteration 610500 completed.
# Iteration 611000 completed.
# Iteration 611500 completed.
# Iteration 612000 completed.
# Iteration 612500 completed.
# Iteration 613000 completed.
# Iteration 613500 completed.
# Iteration 614000 completed.
# Iteration 614500 completed.
# Iteration 615000 completed.
# Iteration 615500 completed.
# Iteration 616000 completed.
# Iteration 616500 completed.
# Iteration 617000 completed.
# Iteration 617500 completed.
# Iteration 618000 completed.
# Iteration 618500 completed.
# Iteration 619000 completed.
# Iteration 619500 completed.
# Iteration 620000 completed.
# Iteration 620500 completed.
# Iteration 621000 completed.
# Iteration 621500 completed.
# Iteration 622000 completed.
# Iteration 622500 completed.
# Iteration 623000 completed.
# Iteration 623500 completed.
# Iteration 624000 completed.
# Iteration 624500 completed.
# Iteration 625000 completed.
# Iteration 625500 completed.
# Iteration 626000 completed.
# Iteration 626500 completed.
# Iteration 627000 completed.
# Iteration 627500 completed.
# Iteration 628000 completed.
# Iteration 628500 completed.
# Iteration 629000 completed.
# Iteration 629500 completed.
# Iteration 630000 completed.
# Iteration 630500 completed.
# Iteration 631000 completed.
# Iteration 631500 completed.
# Iteration 632000 completed.
# Iteration 632500 completed.
# Iteration 633000 completed.
# Iteration 633500 completed.
# Iteration 634000 completed.
# Iteration 634500 completed.
# Iteration 635000 completed.
# Iteration 635500 completed.
# Iteration 636000 completed.
# Iteration 636500 completed.
# Iteration 637000 completed.
# Iteration 637500 completed.
# Iteration 638000 completed.
# Iteration 638500 completed.
# Iteration 639000 completed.
# Iteration 639500 completed.
# Iteration 640000 completed.
# Iteration 640500 completed.
# Iteration 641000 completed.
# Iteration 641500 completed.
# Iteration 642000 completed.
# Iteration 642500 completed.
# Iteration 643000 completed.
# Iteration 643500 completed.
# Iteration 644000 completed.
# Iteration 644500 completed.
# Iteration 645000 completed.
# Iteration 645500 completed.
# Iteration 646000 completed.
# Iteration 646500 completed.
# Iteration 647000 completed.
# Iteration 647500 completed.
# Iteration 648000 completed.
# Iteration 648500 completed.
# Iteration 649000 completed.
# Iteration 649500 completed.
# Iteration 650000 completed.
# Iteration 650500 completed.
# Iteration 651000 completed.
# Iteration 651500 completed.
# Iteration 652000 completed.
# Iteration 652500 completed.
# Iteration 653000 completed.
# Iteration 653500 completed.
# Iteration 654000 completed.
# Iteration 654500 completed.
# Iteration 655000 completed.
# Iteration 655500 completed.
# Iteration 656000 completed.
# Iteration 656500 completed.
# Iteration 657000 completed.
# Iteration 657500 completed.
# Iteration 658000 completed.
# Iteration 658500 completed.
# Iteration 659000 completed.
# Iteration 659500 completed.
# Iteration 660000 completed.
# Iteration 660500 completed.
# Iteration 661000 completed.
# Iteration 661500 completed.
# Iteration 662000 completed.
# Iteration 662500 completed.
# Iteration 663000 completed.
# Iteration 663500 completed.
# Iteration 664000 completed.
# Iteration 664500 completed.
# Iteration 665000 completed.
# Iteration 665500 completed.
# Iteration 666000 completed.
# Iteration 666500 completed.
# Iteration 667000 completed.
# Iteration 667500 completed.
# Iteration 668000 completed.
# Iteration 668500 completed.
# Iteration 669000 completed.
# Iteration 669500 completed.
# Iteration 670000 completed.
# Iteration 670500 completed.
# Iteration 671000 completed.
# Iteration 671500 completed.
# Iteration 672000 completed.
# Iteration 672500 completed.
# Iteration 673000 completed.
# Iteration 673500 completed.
# Iteration 674000 completed.
# Iteration 674500 completed.
# Iteration 675000 completed.
# Iteration 675500 completed.
# Iteration 676000 completed.
# Iteration 676500 completed.
# Iteration 677000 completed.
# Iteration 677500 completed.
# Iteration 678000 completed.
# Iteration 678500 completed.
# Iteration 679000 completed.
# Iteration 679500 completed.
# Iteration 680000 completed.
# Iteration 680500 completed.
# Iteration 681000 completed.
# Iteration 681500 completed.
# Iteration 682000 completed.
# Iteration 682500 completed.
# Iteration 683000 completed.
# Iteration 683500 completed.
# Iteration 684000 completed.
# Iteration 684500 completed.
# Iteration 685000 completed.
# Iteration 685500 completed.
# Iteration 686000 completed.
# Iteration 686500 completed.
# Iteration 687000 completed.
# Iteration 687500 completed.
# Iteration 688000 completed.
# Iteration 688500 completed.
# Iteration 689000 completed.
# Iteration 689500 completed.
# Iteration 690000 completed.
# Iteration 690500 completed.
# Iteration 691000 completed.
# Iteration 691500 completed.
# Iteration 692000 completed.
# Iteration 692500 completed.
# Iteration 693000 completed.
# Iteration 693500 completed.
# Iteration 694000 completed.
# Iteration 694500 completed.
# Iteration 695000 completed.
# Iteration 695500 completed.
# Iteration 696000 completed.
# Iteration 696500 completed.
# Iteration 697000 completed.
# Iteration 697500 completed.
# Iteration 698000 completed.
# Iteration 698500 completed.
# Iteration 699000 completed.
# Iteration 699500 completed.
# Iteration 700000 completed.
# Iteration 700500 completed.
# Iteration 701000 completed.
# Iteration 701500 completed.
# Iteration 702000 completed.
# Iteration 702500 completed.
# Iteration 703000 completed.
# Iteration 703500 completed.
# Iteration 704000 completed.
# Iteration 704500 completed.
# Iteration 705000 completed.
# Iteration 705500 completed.
# Iteration 706000 completed.
# Iteration 706500 completed.
# Iteration 707000 completed.
# Iteration 707500 completed.
# Iteration 708000 completed.
# Iteration 708500 completed.
# Iteration 709000 completed.
# Iteration 709500 completed.
# Iteration 710000 completed.
# Iteration 710500 completed.
# Iteration 711000 completed.
# Iteration 711500 completed.
# Iteration 712000 completed.
# Iteration 712500 completed.
# Iteration 713000 completed.
# Iteration 713500 completed.
# Iteration 714000 completed.
# Iteration 714500 completed.
# Iteration 715000 completed.
# Iteration 715500 completed.
# Iteration 716000 completed.
# Iteration 716500 completed.
# Iteration 717000 completed.
# Iteration 717500 completed.
# Iteration 718000 completed.
# Iteration 718500 completed.
# Iteration 719000 completed.
# Iteration 719500 completed.
# Iteration 720000 completed.
# Iteration 720500 completed.
# Iteration 721000 completed.
# Iteration 721500 completed.
# Iteration 722000 completed.
# Iteration 722500 completed.
# Iteration 723000 completed.
# Iteration 723500 completed.
# Iteration 724000 completed.
# Iteration 724500 completed.
# Iteration 725000 completed.
# Iteration 725500 completed.
# Iteration 726000 completed.
# Iteration 726500 completed.
# Iteration 727000 completed.
# Iteration 727500 completed.
# Iteration 728000 completed.
# Iteration 728500 completed.
# Iteration 729000 completed.
# Iteration 729500 completed.
# Iteration 730000 completed.
# Iteration 730500 completed.
# Iteration 731000 completed.
# Iteration 731500 completed.
# Iteration 732000 completed.
# Iteration 732500 completed.
# Iteration 733000 completed.
# Iteration 733500 completed.
# Iteration 734000 completed.
# Iteration 734500 completed.
# Iteration 735000 completed.
# Iteration 735500 completed.
# Iteration 736000 completed.
# Iteration 736500 completed.
# Iteration 737000 completed.
# Iteration 737500 completed.
# Iteration 738000 completed.
# Iteration 738500 completed.
# Iteration 739000 completed.
# Iteration 739500 completed.
# Iteration 740000 completed.
# Iteration 740500 completed.
# Iteration 741000 completed.
# Iteration 741500 completed.
# Iteration 742000 completed.
# Iteration 742500 completed.
# Iteration 743000 completed.
# Iteration 743500 completed.
# Iteration 744000 completed.
# Iteration 744500 completed.
# Iteration 745000 completed.
# Iteration 745500 completed.
# Iteration 746000 completed.
# Iteration 746500 completed.
# Iteration 747000 completed.
# Iteration 747500 completed.
# Iteration 748000 completed.
# Iteration 748500 completed.
# Iteration 749000 completed.
# Iteration 749500 completed.
# Iteration 750000 completed.
# Iteration 750500 completed.
# Iteration 751000 completed.
# Iteration 751500 completed.
# Iteration 752000 completed.
# Iteration 752500 completed.
# Iteration 753000 completed.
# Iteration 753500 completed.
# Iteration 754000 completed.
# Iteration 754500 completed.
# Iteration 755000 completed.
# Iteration 755500 completed.
# Iteration 756000 completed.
# Iteration 756500 completed.
# Iteration 757000 completed.
# Iteration 757500 completed.
# Iteration 758000 completed.
# Iteration 758500 completed.
# Iteration 759000 completed.
# Iteration 759500 completed.
# Iteration 760000 completed.
# Iteration 760500 completed.
# Iteration 761000 completed.
# Iteration 761500 completed.
# Iteration 762000 completed.
# Iteration 762500 completed.
# Iteration 763000 completed.
# Iteration 763500 completed.
# Iteration 764000 completed.
# Iteration 764500 completed.
# Iteration 765000 completed.
# Iteration 765500 completed.
# Iteration 766000 completed.
# Iteration 766500 completed.
# Iteration 767000 completed.
# Iteration 767500 completed.
# Iteration 768000 completed.
# Iteration 768500 completed.
# Iteration 769000 completed.
# Iteration 769500 completed.
# Iteration 770000 completed.
# Iteration 770500 completed.
# Iteration 771000 completed.
# Iteration 771500 completed.
# Iteration 772000 completed.
# Iteration 772500 completed.
# Iteration 773000 completed.
# Iteration 773500 completed.
# Iteration 774000 completed.
# Iteration 774500 completed.
# Iteration 775000 completed.
# Iteration 775500 completed.
# Iteration 776000 completed.
# Iteration 776500 completed.
# Iteration 777000 completed.
# Iteration 777500 completed.
# Iteration 778000 completed.
# Iteration 778500 completed.
# Iteration 779000 completed.
# Iteration 779500 completed.
# Iteration 780000 completed.
# Iteration 780500 completed.
# Iteration 781000 completed.
# Iteration 781500 completed.
# Iteration 782000 completed.
# Iteration 782500 completed.
# Iteration 783000 completed.
# Iteration 783500 completed.
# Iteration 784000 completed.
# Iteration 784500 completed.
# Iteration 785000 completed.
# Iteration 785500 completed.
# Iteration 786000 completed.
# Iteration 786500 completed.
# Iteration 787000 completed.
# Iteration 787500 completed.
# Iteration 788000 completed.
# Iteration 788500 completed.
# Iteration 789000 completed.
# Iteration 789500 completed.
# Iteration 790000 completed.
# Iteration 790500 completed.
# Iteration 791000 completed.
# Iteration 791500 completed.
# Iteration 792000 completed.
# Iteration 792500 completed.
# Iteration 793000 completed.
# Iteration 793500 completed.
# Iteration 794000 completed.
# Iteration 794500 completed.
# Iteration 795000 completed.
# Iteration 795500 completed.
# Iteration 796000 completed.
# Iteration 796500 completed.
# Iteration 797000 completed.
# Iteration 797500 completed.
# Iteration 798000 completed.
# Iteration 798500 completed.
# Iteration 799000 completed.
# Iteration 799500 completed.
# Iteration 800000 completed.
# Iteration 800500 completed.
# Iteration 801000 completed.
# Iteration 801500 completed.
# Iteration 802000 completed.
# Iteration 802500 completed.
# Iteration 803000 completed.
# Iteration 803500 completed.
# Iteration 804000 completed.
# Iteration 804500 completed.
# Iteration 805000 completed.
# Iteration 805500 completed.
# Iteration 806000 completed.
# Iteration 806500 completed.
# Iteration 807000 completed.
# Iteration 807500 completed.
# Iteration 808000 completed.
# Iteration 808500 completed.
# Iteration 809000 completed.
# Iteration 809500 completed.
# Iteration 810000 completed.
# Iteration 810500 completed.
# Iteration 811000 completed.
# Iteration 811500 completed.
# Iteration 812000 completed.
# Iteration 812500 completed.
# Iteration 813000 completed.
# Iteration 813500 completed.
# Iteration 814000 completed.
# Iteration 814500 completed.
# Iteration 815000 completed.
# Iteration 815500 completed.
# Iteration 816000 completed.
# Iteration 816500 completed.
# Iteration 817000 completed.
# Iteration 817500 completed.
# Iteration 818000 completed.
# Iteration 818500 completed.
# Iteration 819000 completed.
# Iteration 819500 completed.
# Iteration 820000 completed.
# Iteration 820500 completed.
# Iteration 821000 completed.
# Iteration 821500 completed.
# Iteration 822000 completed.
# Iteration 822500 completed.
# Iteration 823000 completed.
# Iteration 823500 completed.
# Iteration 824000 completed.
# Iteration 824500 completed.
# Iteration 825000 completed.
# Iteration 825500 completed.
# Iteration 826000 completed.
# Iteration 826500 completed.
# Iteration 827000 completed.
# Iteration 827500 completed.
# Iteration 828000 completed.
# Iteration 828500 completed.
# Iteration 829000 completed.
# Iteration 829500 completed.
# Iteration 830000 completed.
# Iteration 830500 completed.
# Iteration 831000 completed.
# Iteration 831500 completed.
# Iteration 832000 completed.
# Iteration 832500 completed.
# Iteration 833000 completed.
# Iteration 833500 completed.
# Iteration 834000 completed.
# Iteration 834500 completed.
# Iteration 835000 completed.
# Iteration 835500 completed.
# Iteration 836000 completed.
# Iteration 836500 completed.
# Iteration 837000 completed.
# Iteration 837500 completed.
# Iteration 838000 completed.
# Iteration 838500 completed.
# Iteration 839000 completed.
# Iteration 839500 completed.
# Iteration 840000 completed.
# Iteration 840500 completed.
# Iteration 841000 completed.
# Iteration 841500 completed.
# Iteration 842000 completed.
# Iteration 842500 completed.
# Iteration 843000 completed.
# Iteration 843500 completed.
# Iteration 844000 completed.
# Iteration 844500 completed.
# Iteration 845000 completed.
# Iteration 845500 completed.
# Iteration 846000 completed.
# Iteration 846500 completed.
# Iteration 847000 completed.
# Iteration 847500 completed.
# Iteration 848000 completed.
# Iteration 848500 completed.
# Iteration 849000 completed.
# Iteration 849500 completed.
# Iteration 850000 completed.
# Iteration 850500 completed.
# Iteration 851000 completed.
# Iteration 851500 completed.
# Iteration 852000 completed.
# Iteration 852500 completed.
# Iteration 853000 completed.
# Iteration 853500 completed.
# Iteration 854000 completed.
# Iteration 854500 completed.
# Iteration 855000 completed.
# Iteration 855500 completed.
# Iteration 856000 completed.
# Iteration 856500 completed.
# Iteration 857000 completed.
# Iteration 857500 completed.
# Iteration 858000 completed.
# Iteration 858500 completed.
# Iteration 859000 completed.
# Iteration 859500 completed.
# Iteration 860000 completed.
# Iteration 860500 completed.
# Iteration 861000 completed.
# Iteration 861500 completed.
# Iteration 862000 completed.
# Iteration 862500 completed.
# Iteration 863000 completed.
# Iteration 863500 completed.
# Iteration 864000 completed.
# Iteration 864500 completed.
# Iteration 865000 completed.
# Iteration 865500 completed.
# Iteration 866000 completed.
# Iteration 866500 completed.
# Iteration 867000 completed.
# Iteration 867500 completed.
# Iteration 868000 completed.
# Iteration 868500 completed.
# Iteration 869000 completed.
# Iteration 869500 completed.
# Iteration 870000 completed.
# Iteration 870500 completed.
# Iteration 871000 completed.
# Iteration 871500 completed.
# Iteration 872000 completed.
# Iteration 872500 completed.
# Iteration 873000 completed.
# Iteration 873500 completed.
# Iteration 874000 completed.
# Iteration 874500 completed.
# Iteration 875000 completed.
# Iteration 875500 completed.
# Iteration 876000 completed.
# Iteration 876500 completed.
# Iteration 877000 completed.
# Iteration 877500 completed.
# Iteration 878000 completed.
# Iteration 878500 completed.
# Iteration 879000 completed.
# Iteration 879500 completed.
# Iteration 880000 completed.
# Iteration 880500 completed.
# Iteration 881000 completed.
# Iteration 881500 completed.
# Iteration 882000 completed.
# Iteration 882500 completed.
# Iteration 883000 completed.
# Iteration 883500 completed.
# Iteration 884000 completed.
# Iteration 884500 completed.
# Iteration 885000 completed.
# Iteration 885500 completed.
# Iteration 886000 completed.
# Iteration 886500 completed.
# Iteration 887000 completed.
# Iteration 887500 completed.
# Iteration 888000 completed.
# Iteration 888500 completed.
# Iteration 889000 completed.
# Iteration 889500 completed.
# Iteration 890000 completed.
# Iteration 890500 completed.
# Iteration 891000 completed.
# Iteration 891500 completed.
# Iteration 892000 completed.
# Iteration 892500 completed.
# Iteration 893000 completed.
# Iteration 893500 completed.
# Iteration 894000 completed.
# Iteration 894500 completed.
# Iteration 895000 completed.
# Iteration 895500 completed.
# Iteration 896000 completed.
# Iteration 896500 completed.
# Iteration 897000 completed.
# Iteration 897500 completed.
# Iteration 898000 completed.
# Iteration 898500 completed.
# Iteration 899000 completed.
# Iteration 899500 completed.
# Iteration 900000 completed.
# Iteration 900500 completed.
# Iteration 901000 completed.
# Iteration 901500 completed.
# Iteration 902000 completed.
# Iteration 902500 completed.
# Iteration 903000 completed.
# Iteration 903500 completed.
# Iteration 904000 completed.
# Iteration 904500 completed.
# Iteration 905000 completed.
# Iteration 905500 completed.
# Iteration 906000 completed.
# Iteration 906500 completed.
# Iteration 907000 completed.
# Iteration 907500 completed.
# Iteration 908000 completed.
# Iteration 908500 completed.
# Iteration 909000 completed.
# Iteration 909500 completed.
# Iteration 910000 completed.
# Iteration 910500 completed.
# Iteration 911000 completed.
# Iteration 911500 completed.
# Iteration 912000 completed.
# Iteration 912500 completed.
# Iteration 913000 completed.
# Iteration 913500 completed.
# Iteration 914000 completed.
# Iteration 914500 completed.
# Iteration 915000 completed.
# Iteration 915500 completed.
# Iteration 916000 completed.
# Iteration 916500 completed.
# Iteration 917000 completed.
# Iteration 917500 completed.
# Iteration 918000 completed.
# Iteration 918500 completed.
# Iteration 919000 completed.
# Iteration 919500 completed.
# Iteration 920000 completed.
# Iteration 920500 completed.
# Iteration 921000 completed.
# Iteration 921500 completed.
# Iteration 922000 completed.
# Iteration 922500 completed.
# Iteration 923000 completed.
# Iteration 923500 completed.
# Iteration 924000 completed.
# Iteration 924500 completed.
# Iteration 925000 completed.
# Iteration 925500 completed.
# Iteration 926000 completed.
# Iteration 926500 completed.
# Iteration 927000 completed.
# Iteration 927500 completed.
# Iteration 928000 completed.
# Iteration 928500 completed.
# Iteration 929000 completed.
# Iteration 929500 completed.
# Iteration 930000 completed.
# Iteration 930500 completed.
# Iteration 931000 completed.
# Iteration 931500 completed.
# Iteration 932000 completed.
# Iteration 932500 completed.
# Iteration 933000 completed.
# Iteration 933500 completed.
# Iteration 934000 completed.
# Iteration 934500 completed.
# Iteration 935000 completed.
# Iteration 935500 completed.
# Iteration 936000 completed.
# Iteration 936500 completed.
# Iteration 937000 completed.
# Iteration 937500 completed.
# Iteration 938000 completed.
# Iteration 938500 completed.
# Iteration 939000 completed.
# Iteration 939500 completed.
# Iteration 940000 completed.
# Iteration 940500 completed.
# Iteration 941000 completed.
# Iteration 941500 completed.
# Iteration 942000 completed.
# Iteration 942500 completed.
# Iteration 943000 completed.
# Iteration 943500 completed.
# Iteration 944000 completed.
# Iteration 944500 completed.
# Iteration 945000 completed.
# Iteration 945500 completed.
# Iteration 946000 completed.
# Iteration 946500 completed.
# Iteration 947000 completed.
# Iteration 947500 completed.
# Iteration 948000 completed.
# Iteration 948500 completed.
# Iteration 949000 completed.
# Iteration 949500 completed.
# Iteration 950000 completed.
# Iteration 950500 completed.
# Iteration 951000 completed.
# Iteration 951500 completed.
# Iteration 952000 completed.
# Iteration 952500 completed.
# Iteration 953000 completed.
# Iteration 953500 completed.
# Iteration 954000 completed.
# Iteration 954500 completed.
# Iteration 955000 completed.
# Iteration 955500 completed.
# Iteration 956000 completed.
# Iteration 956500 completed.
# Iteration 957000 completed.
# Iteration 957500 completed.
# Iteration 958000 completed.
# Iteration 958500 completed.
# Iteration 959000 completed.
# Iteration 959500 completed.
# Iteration 960000 completed.
# Iteration 960500 completed.
# Iteration 961000 completed.
# Iteration 961500 completed.
# Iteration 962000 completed.
# Iteration 962500 completed.
# Iteration 963000 completed.
# Iteration 963500 completed.
# Iteration 964000 completed.
# Iteration 964500 completed.
# Iteration 965000 completed.
# Iteration 965500 completed.
# Iteration 966000 completed.
# Iteration 966500 completed.
# Iteration 967000 completed.
# Iteration 967500 completed.
# Iteration 968000 completed.
# Iteration 968500 completed.
# Iteration 969000 completed.
# Iteration 969500 completed.
# Iteration 970000 completed.
# Iteration 970500 completed.
# Iteration 971000 completed.
# Iteration 971500 completed.
# Iteration 972000 completed.
# Iteration 972500 completed.
# Iteration 973000 completed.
# Iteration 973500 completed.
# Iteration 974000 completed.
# Iteration 974500 completed.
# Iteration 975000 completed.
# Iteration 975500 completed.
# Iteration 976000 completed.
# Iteration 976500 completed.
# Iteration 977000 completed.
# Iteration 977500 completed.
# Iteration 978000 completed.
# Iteration 978500 completed.
# Iteration 979000 completed.
# Iteration 979500 completed.
# Iteration 980000 completed.
# Iteration 980500 completed.
# Iteration 981000 completed.
# Iteration 981500 completed.
# Iteration 982000 completed.
# Iteration 982500 completed.
# Iteration 983000 completed.
# Iteration 983500 completed.
# Iteration 984000 completed.
# Iteration 984500 completed.
# Iteration 985000 completed.
# Iteration 985500 completed.
# Iteration 986000 completed.
# Iteration 986500 completed.
# Iteration 987000 completed.
# Iteration 987500 completed.
# Iteration 988000 completed.
# Iteration 988500 completed.
# Iteration 989000 completed.
# Iteration 989500 completed.
# Iteration 990000 completed.
# Iteration 990500 completed.
# Iteration 991000 completed.
# Iteration 991500 completed.
# Iteration 992000 completed.
# Iteration 992500 completed.
# Iteration 993000 completed.
# Iteration 993500 completed.
# Iteration 994000 completed.
# Iteration 994500 completed.
# Iteration 995000 completed.
# Iteration 995500 completed.
# Iteration 996000 completed.
# Iteration 996500 completed.
# Iteration 997000 completed.
# Iteration 997500 completed.
# Iteration 998000 completed.
# Iteration 998500 completed.
# Iteration 999000 completed.
# Iteration 999500 completed.

# %%
corner_plot(samples, params)
plot_marginal(samples, x_true)

# %% [markdown]
# ## Model with intrinsic dispersion and selection function

# %%
mu_theta= 0.0
sigma_theta_squared= 4.0 ** 2
sigma_0_inv= np.linalg.inv(np.diag([sigma_theta_squared, sigma_theta_squared]))
mu_0 = np.array([mu_theta, mu_theta])
params = Parameters( 
        N = 200,
        sigma_int_sqrd = 0.25,
        theta_0 = 1.0,
        theta_1 = 0.5,
        x0 = 0,
        Rx = 1,    
        sigma_x_sqrd = 1,
        sigma_y_sqrd = 0.25,
        mu_x0 = 1.0,
        sigma_x0_sqrd = 1.0,
        alpha_R = 0.1,
        beta_R = 1,
        alpha_sigma = 0.1,
        beta_sigma = 1,
        mu_theta= 0.0,
        sigma_theta_squared= 4.0 ** 2,
        sigma_0_inv=sigma_0_inv,
        mu_0=mu_0,
        gamma=0.5
        )
# Set random seed for reproducibility
np.random.seed(42)

x_true, mu_y, y_true = generate_latents(params)
selected_indices = np.random.binomial(1, 1 / (1 + np.exp(-params.gamma * y_true)), params.N)

N_obs = np.sum(selected_indices)
# Reorder arrays based on selection
x_true_ordered = np.zeros_like(x_true)
y_true_ordered = np.zeros_like(y_true)
mu_y_ordered = np.zeros_like(mu_y)

# Copy selected indices first
x_true_ordered[:N_obs] = x_true[selected_indices == 1]
y_true_ordered[:N_obs] = y_true[selected_indices == 1]
mu_y_ordered[:N_obs] = mu_y[selected_indices == 1]

# Copy non-selected indices after
x_true_ordered[N_obs:] = x_true[selected_indices == 0]
y_true_ordered[N_obs:] = y_true[selected_indices == 0]
mu_y_ordered[N_obs:] = mu_y[selected_indices == 0]

# Replace original arrays with ordered versions
x_true = x_true_ordered
y_true = y_true_ordered
mu_y = mu_y_ordered

x_obs, y_obs = generate_obs(x_true[:N_obs], y_true[:N_obs], params, n=N_obs)
x_miss, y_miss = generate_obs(x_true[N_obs:], y_true[N_obs:], params, n=(params.N - N_obs))

# Plot the generated data
y_true_wo_int_dip = true_relationship(x_true, params.theta_0, params.theta_1)

# %%
plt.figure(figsize=(8, 6))
plt.errorbar(x_obs, y_obs, xerr=params.sigma_x_sqrd, yerr=np.sqrt(params.sigma_y_sqrd+params.sigma_int_sqrd), fmt='o', ecolor='gray', capsize=3, label='Observed data')
plt.errorbar(x_miss, y_miss, xerr=params.sigma_x_sqrd, yerr=np.sqrt(params.sigma_y_sqrd), fmt='o', ecolor='gray', capsize=3, label='Missing data')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Synthetic Data Generated from Errors-in-Variables Model')
plt.grid(True)
plt.plot(x_true, y_true_wo_int_dip, label='True Relationship', color='red')
plt.legend()
plt.show()

# %%
# Number of iterations for Gibbs sampler
num_iterations = 200000

samples = init_arrays(num_iterations,params)
# Initial values

vars = {
    "theta_0": 0.0,
    "theta_1": 0.0,
    "x0": np.mean(x_obs),
    "Rx2": np.var(x_obs),
    "x_i": np.concatenate([x_obs, x_miss]),
    "y_i": np.concatenate([x_obs, x_miss]),
    "sigma_int_sqrd": np.std(y_obs)/2,
    "N_obs": N_obs,
    "N": params.N
}

# Start Gibbs sampling
for t in range(num_iterations):
    # Step 1: Sample x_i, x_j
    vars["x_i"][:vars["N_obs"]] = sample_x_i(vars, params, x_obs)
    vars["x_i"][vars["N_obs"]:] = sample_x_j(vars, params)
    # Step 2: Sample y_i
    vars["y_i"][:vars["N_obs"]] = sample_y_i_w_selection(vars, params, y_obs)
    vars["y_i"][vars["N_obs"]:] = sample_y_j(vars, params)
    # Step 3: Sample theta_0 and theta_1 jointly
    vars["theta_0"], vars["theta_1"] = sample_theta(vars, params)
    # Step 4: Sample x0
    vars["x0"] = sample_x0(vars, params)
    # Step 5: Sample Rx^2
    vars["Rx2"] = sample_Rx2(vars, params)
    #print("Rx2",vars["Rx2"])
    # Step 6: Sample sigma_int_sqrd
    vars["sigma_int_sqrd"] = sample_sigma_int_sqrd(vars, params)
    
    for key in samples.keys():
        samples[key][t] = vars[key]
    
    if t % 500 == 0:
        print(f"Iteration {t} completed.")

# Convert Rx^2 samples to Rx samples
Rx_samples = np.sqrt(samples["Rx2"])
samples["Rx"] = Rx_samples
# Convert sigma_int_sqrd_sqrd^2 samples to sigma_int_sqrd_sqrd samples
sigma_int_sqrd_samples = np.sqrt(samples["sigma_int_sqrd"])
samples["sigma_int"] = sigma_int_sqrd_samples

# Discard burn-in samples
burn_in = 50000
for key in samples:
    samples[key] = samples[key][burn_in:]
# Out:
# Iteration 0 completed.
# Iteration 500 completed.
# Iteration 1000 completed.
# Iteration 1500 completed.
# Iteration 2000 completed.
# Iteration 2500 completed.
# Iteration 3000 completed.
# Iteration 3500 completed.
# Iteration 4000 completed.
# Iteration 4500 completed.
# Iteration 5000 completed.
# Iteration 5500 completed.
# Iteration 6000 completed.
# Iteration 6500 completed.
# Iteration 7000 completed.
# Iteration 7500 completed.
# Iteration 8000 completed.
# Iteration 8500 completed.
# Iteration 9000 completed.
# Iteration 9500 completed.
# Iteration 10000 completed.
# Iteration 10500 completed.
# Iteration 11000 completed.
# Iteration 11500 completed.
# Iteration 12000 completed.
# Iteration 12500 completed.
# Iteration 13000 completed.
# Iteration 13500 completed.
# Iteration 14000 completed.
# Iteration 14500 completed.
# Iteration 15000 completed.
# Iteration 15500 completed.
# Iteration 16000 completed.
# Iteration 16500 completed.
# Iteration 17000 completed.
# Iteration 17500 completed.
# Iteration 18000 completed.
# Iteration 18500 completed.
# Iteration 19000 completed.
# Iteration 19500 completed.
# Iteration 20000 completed.
# Iteration 20500 completed.
# Iteration 21000 completed.
# Iteration 21500 completed.
# Iteration 22000 completed.
# Iteration 22500 completed.
# Iteration 23000 completed.
# Iteration 23500 completed.
# Iteration 24000 completed.
# Iteration 24500 completed.
# Iteration 25000 completed.
# Iteration 25500 completed.
# Iteration 26000 completed.
# Iteration 26500 completed.
# Iteration 27000 completed.
# Iteration 27500 completed.
# Iteration 28000 completed.
# Iteration 28500 completed.
# Iteration 29000 completed.
# Iteration 29500 completed.
# Iteration 30000 completed.
# Iteration 30500 completed.
# Iteration 31000 completed.
# Iteration 31500 completed.
# Iteration 32000 completed.
# Iteration 32500 completed.
# Iteration 33000 completed.
# Iteration 33500 completed.
# Iteration 34000 completed.
# Iteration 34500 completed.
# Iteration 35000 completed.
# Iteration 35500 completed.
# Iteration 36000 completed.
# Iteration 36500 completed.
# Iteration 37000 completed.
# Iteration 37500 completed.
# Iteration 38000 completed.
# Iteration 38500 completed.
# Iteration 39000 completed.
# Iteration 39500 completed.
# Iteration 40000 completed.
# Iteration 40500 completed.
# Iteration 41000 completed.
# Iteration 41500 completed.
# Iteration 42000 completed.
# Iteration 42500 completed.
# Iteration 43000 completed.
# Iteration 43500 completed.
# Iteration 44000 completed.
# Iteration 44500 completed.
# Iteration 45000 completed.
# Iteration 45500 completed.
# Iteration 46000 completed.
# Iteration 46500 completed.
# Iteration 47000 completed.
# Iteration 47500 completed.
# Iteration 48000 completed.
# Iteration 48500 completed.
# Iteration 49000 completed.
# Iteration 49500 completed.
# Iteration 50000 completed.
# Iteration 50500 completed.
# Iteration 51000 completed.
# Iteration 51500 completed.
# Iteration 52000 completed.
# Iteration 52500 completed.
# Iteration 53000 completed.
# Iteration 53500 completed.
# Iteration 54000 completed.
# Iteration 54500 completed.
# Iteration 55000 completed.
# Iteration 55500 completed.
# Iteration 56000 completed.
# Iteration 56500 completed.
# Iteration 57000 completed.
# Iteration 57500 completed.
# Iteration 58000 completed.
# Iteration 58500 completed.
# Iteration 59000 completed.
# Iteration 59500 completed.
# Iteration 60000 completed.
# Iteration 60500 completed.
# Iteration 61000 completed.
# Iteration 61500 completed.
# Iteration 62000 completed.
# Iteration 62500 completed.
# Iteration 63000 completed.
# Iteration 63500 completed.
# Iteration 64000 completed.
# Iteration 64500 completed.
# Iteration 65000 completed.
# Iteration 65500 completed.
# Iteration 66000 completed.
# Iteration 66500 completed.
# Iteration 67000 completed.
# Iteration 67500 completed.
# Iteration 68000 completed.
# Iteration 68500 completed.
# Iteration 69000 completed.
# Iteration 69500 completed.
# Iteration 70000 completed.
# Iteration 70500 completed.
# Iteration 71000 completed.
# Iteration 71500 completed.
# Iteration 72000 completed.
# Iteration 72500 completed.
# Iteration 73000 completed.
# Iteration 73500 completed.
# Iteration 74000 completed.
# Iteration 74500 completed.
# Iteration 75000 completed.
# Iteration 75500 completed.
# Iteration 76000 completed.
# Iteration 76500 completed.
# Iteration 77000 completed.
# Iteration 77500 completed.
# Iteration 78000 completed.
# Iteration 78500 completed.
# Iteration 79000 completed.
# Iteration 79500 completed.
# Iteration 80000 completed.
# Iteration 80500 completed.
# Iteration 81000 completed.
# Iteration 81500 completed.
# Iteration 82000 completed.
# Iteration 82500 completed.
# Iteration 83000 completed.
# Iteration 83500 completed.
# Iteration 84000 completed.
# Iteration 84500 completed.
# Iteration 85000 completed.
# Iteration 85500 completed.
# Iteration 86000 completed.
# Iteration 86500 completed.
# Iteration 87000 completed.
# Iteration 87500 completed.
# Iteration 88000 completed.
# Iteration 88500 completed.
# Iteration 89000 completed.
# Iteration 89500 completed.
# Iteration 90000 completed.
# Iteration 90500 completed.
# Iteration 91000 completed.
# Iteration 91500 completed.
# Iteration 92000 completed.
# Iteration 92500 completed.
# Iteration 93000 completed.
# Iteration 93500 completed.
# Iteration 94000 completed.
# Iteration 94500 completed.
# Iteration 95000 completed.
# Iteration 95500 completed.
# Iteration 96000 completed.
# Iteration 96500 completed.
# Iteration 97000 completed.
# Iteration 97500 completed.
# Iteration 98000 completed.
# Iteration 98500 completed.
# Iteration 99000 completed.
# Iteration 99500 completed.
# Iteration 100000 completed.
# Iteration 100500 completed.
# Iteration 101000 completed.
# Iteration 101500 completed.
# Iteration 102000 completed.
# Iteration 102500 completed.
# Iteration 103000 completed.
# Iteration 103500 completed.
# Iteration 104000 completed.
# Iteration 104500 completed.
# Iteration 105000 completed.
# Iteration 105500 completed.
# Iteration 106000 completed.
# Iteration 106500 completed.
# Iteration 107000 completed.
# Iteration 107500 completed.
# Iteration 108000 completed.
# Iteration 108500 completed.
# Iteration 109000 completed.
# Iteration 109500 completed.
# Iteration 110000 completed.
# Iteration 110500 completed.
# Iteration 111000 completed.
# Iteration 111500 completed.
# Iteration 112000 completed.
# Iteration 112500 completed.
# Iteration 113000 completed.
# Iteration 113500 completed.
# Iteration 114000 completed.
# Iteration 114500 completed.
# Iteration 115000 completed.
# Iteration 115500 completed.
# Iteration 116000 completed.
# Iteration 116500 completed.
# Iteration 117000 completed.
# Iteration 117500 completed.
# Iteration 118000 completed.
# Iteration 118500 completed.
# Iteration 119000 completed.
# Iteration 119500 completed.
# Iteration 120000 completed.
# Iteration 120500 completed.
# Iteration 121000 completed.
# Iteration 121500 completed.
# Iteration 122000 completed.
# Iteration 122500 completed.
# Iteration 123000 completed.
# Iteration 123500 completed.
# Iteration 124000 completed.
# Iteration 124500 completed.
# Iteration 125000 completed.
# Iteration 125500 completed.
# Iteration 126000 completed.
# Iteration 126500 completed.
# Iteration 127000 completed.
# Iteration 127500 completed.
# Iteration 128000 completed.
# Iteration 128500 completed.
# Iteration 129000 completed.
# Iteration 129500 completed.
# Iteration 130000 completed.
# Iteration 130500 completed.
# Iteration 131000 completed.
# Iteration 131500 completed.
# Iteration 132000 completed.
# Iteration 132500 completed.
# Iteration 133000 completed.
# Iteration 133500 completed.
# Iteration 134000 completed.
# Iteration 134500 completed.
# Iteration 135000 completed.
# Iteration 135500 completed.
# Iteration 136000 completed.
# Iteration 136500 completed.
# Iteration 137000 completed.
# Iteration 137500 completed.
# Iteration 138000 completed.
# Iteration 138500 completed.
# Iteration 139000 completed.
# Iteration 139500 completed.
# Iteration 140000 completed.
# Iteration 140500 completed.
# Iteration 141000 completed.
# Iteration 141500 completed.
# Iteration 142000 completed.
# Iteration 142500 completed.
# Iteration 143000 completed.
# Iteration 143500 completed.
# Iteration 144000 completed.
# Iteration 144500 completed.
# Iteration 145000 completed.
# Iteration 145500 completed.
# Iteration 146000 completed.
# Iteration 146500 completed.
# Iteration 147000 completed.
# Iteration 147500 completed.
# Iteration 148000 completed.
# Iteration 148500 completed.
# Iteration 149000 completed.
# Iteration 149500 completed.
# Iteration 150000 completed.
# Iteration 150500 completed.
# Iteration 151000 completed.
# Iteration 151500 completed.
# Iteration 152000 completed.
# Iteration 152500 completed.
# Iteration 153000 completed.
# Iteration 153500 completed.
# Iteration 154000 completed.
# Iteration 154500 completed.
# Iteration 155000 completed.
# Iteration 155500 completed.
# Iteration 156000 completed.
# Iteration 156500 completed.
# Iteration 157000 completed.
# Iteration 157500 completed.
# Iteration 158000 completed.
# Iteration 158500 completed.
# Iteration 159000 completed.
# Iteration 159500 completed.
# Iteration 160000 completed.
# Iteration 160500 completed.
# Iteration 161000 completed.
# Iteration 161500 completed.
# Iteration 162000 completed.
# Iteration 162500 completed.
# Iteration 163000 completed.
# Iteration 163500 completed.
# Iteration 164000 completed.
# Iteration 164500 completed.
# Iteration 165000 completed.
# Iteration 165500 completed.
# Iteration 166000 completed.
# Iteration 166500 completed.
# Iteration 167000 completed.
# Iteration 167500 completed.
# Iteration 168000 completed.
# Iteration 168500 completed.
# Iteration 169000 completed.
# Iteration 169500 completed.
# Iteration 170000 completed.
# Iteration 170500 completed.
# Iteration 171000 completed.
# Iteration 171500 completed.
# Iteration 172000 completed.
# Iteration 172500 completed.
# Iteration 173000 completed.
# Iteration 173500 completed.
# Iteration 174000 completed.
# Iteration 174500 completed.
# Iteration 175000 completed.
# Iteration 175500 completed.
# Iteration 176000 completed.
# Iteration 176500 completed.
# Iteration 177000 completed.
# Iteration 177500 completed.
# Iteration 178000 completed.
# Iteration 178500 completed.
# Iteration 179000 completed.
# Iteration 179500 completed.
# Iteration 180000 completed.
# Iteration 180500 completed.
# Iteration 181000 completed.
# Iteration 181500 completed.
# Iteration 182000 completed.
# Iteration 182500 completed.
# Iteration 183000 completed.
# Iteration 183500 completed.
# Iteration 184000 completed.
# Iteration 184500 completed.
# Iteration 185000 completed.
# Iteration 185500 completed.
# Iteration 186000 completed.
# Iteration 186500 completed.
# Iteration 187000 completed.
# Iteration 187500 completed.
# Iteration 188000 completed.
# Iteration 188500 completed.
# Iteration 189000 completed.
# Iteration 189500 completed.
# Iteration 190000 completed.
# Iteration 190500 completed.
# Iteration 191000 completed.
# Iteration 191500 completed.
# Iteration 192000 completed.
# Iteration 192500 completed.
# Iteration 193000 completed.
# Iteration 193500 completed.
# Iteration 194000 completed.
# Iteration 194500 completed.
# Iteration 195000 completed.
# Iteration 195500 completed.
# Iteration 196000 completed.
# Iteration 196500 completed.
# Iteration 197000 completed.
# Iteration 197500 completed.
# Iteration 198000 completed.
# Iteration 198500 completed.
# Iteration 199000 completed.
# Iteration 199500 completed.

# %%
corner_plot(samples, params)
plot_marginal(samples, x_true)
